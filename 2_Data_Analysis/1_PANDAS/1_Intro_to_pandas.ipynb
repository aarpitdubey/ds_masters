# %%
# importing pandas and using aliasing name "pd"
import pandas as pd

# %%
# To read csv file (or) player dataset pandas has built-in method that is read_csv()
pd.read_csv('../dataset/Player.csv')
# Out:
#      Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0            1       SC Ganguly   8-Jul-72    Left_Hand    Right-arm medium
# 1            2      BB McCullum  27-Sep-81   Right_Hand    Right-arm medium
# 2            3       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3            4        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4            5  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
# ..         ...              ...        ...          ...                 ...
# 518        519      Subroto Das        NaN          NaN                 NaN
# 519        520     K Srinivasan        NaN          NaN                 NaN
# 520        521        VK Sharma        NaN          NaN                 NaN
# 521        523      AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524      B Aparajith   8-Jul-94   Right_Hand  Right-arm offbreak
#
#          Country  Is_Umpire  Unnamed: 7
# ...

# %%
# Storing the dataset / data frame in df variable
df = pd.read_csv('../dataset/Player.csv')

# %%
# To show 1st 5-records (By Default) we use head() method
df.head()
# Out:
#    Player_Id      Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 0          1       SC Ganguly   8-Jul-72    Left_Hand    Right-arm medium
# 1          2      BB McCullum  27-Sep-81   Right_Hand    Right-arm medium
# 2          3       RT Ponting  19-Dec-74   Right_Hand    Right-arm medium
# 3          4        DJ Hussey  15-Jul-77   Right_Hand  Right-arm offbreak
# 4          5  Mohammad Hafeez  17-Oct-80   Right_Hand  Right-arm offbreak
#
#        Country  Is_Umpire  Unnamed: 7
# 0        India          0         NaN
# 1  New Zealand          0         NaN
# 2    Australia          0         NaN
# 3    Australia          0         NaN
# 4     Pakistan          0         NaN

# %%
# To show more than 5-records we can enter the values b/w 0 to the number of rows
# To show 10 records
df.head(10)
# Out:
#    Player_Id      Player_Name        DOB Batting_Hand          Bowling_Skill  \
# 0          1       SC Ganguly   8-Jul-72    Left_Hand       Right-arm medium
# 1          2      BB McCullum  27-Sep-81   Right_Hand       Right-arm medium
# 2          3       RT Ponting  19-Dec-74   Right_Hand       Right-arm medium
# 3          4        DJ Hussey  15-Jul-77   Right_Hand     Right-arm offbreak
# 4          5  Mohammad Hafeez  17-Oct-80   Right_Hand     Right-arm offbreak
# 5          6         R Dravid  11-Jan-73   Right_Hand     Right-arm offbreak
# 6          7         W Jaffer  16-Feb-78   Right_Hand     Right-arm offbreak
# 7          8          V Kohli   5-Nov-88   Right_Hand       Right-arm medium
# 8          9        JH Kallis  16-Oct-75   Right_Hand  Right-arm fast-medium
# 9         10         CL White  18-Aug-83   Right_Hand        Legbreak googly
#
#         Country  Is_Umpire  Unnamed: 7
# 0         India          0         NaN
# 1   New Zealand          0         NaN
# ...

# %%
# To get the last row values
df.loc[df['Player_Id'] == len(df)+1]
# Out:
#      Player_Id  Player_Name       DOB Batting_Hand       Bowling_Skill  \
# 522        524  B Aparajith  8-Jul-94   Right_Hand  Right-arm offbreak
#
#     Country  Is_Umpire  Unnamed: 7
# 522   India          0         NaN

# %%
# To get bottom 5-records (By default) we use tail()
df.tail()
# Out:
#      Player_Id   Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 518        519   Subroto Das        NaN          NaN                 NaN
# 519        520  K Srinivasan        NaN          NaN                 NaN
# 520        521     VK Sharma        NaN          NaN                 NaN
# 521        523   AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524   B Aparajith   8-Jul-94   Right_Hand  Right-arm offbreak
#
#     Country  Is_Umpire  Unnamed: 7
# 518   India          1         NaN
# 519   India          1         NaN
# 520   India          1         NaN
# 521   India          0         NaN
# 522   India          0         NaN

# %%
df.tail(10)
# Out:
#      Player_Id     Player_Name        DOB Batting_Hand       Bowling_Skill  \
# 513        514       I Shivram        NaN          NaN                 NaN
# 514        515       SD Ranade        NaN          NaN                 NaN
# 515        516  TH Wijewardene        NaN          NaN                 NaN
# 516        517         AL Hill        NaN          NaN                 NaN
# 517        518       RJ Tucker        NaN          NaN                 NaN
# 518        519     Subroto Das        NaN          NaN                 NaN
# 519        520    K Srinivasan        NaN          NaN                 NaN
# 520        521       VK Sharma        NaN          NaN                 NaN
# 521        523     AV Wankhade  14-Mar-92   Right_Hand                 NaN
# 522        524     B Aparajith   8-Jul-94   Right_Hand  Right-arm offbreak
#
#          Country  Is_Umpire  Unnamed: 7
# 513        India          1         NaN
# 514        India          1         NaN
# ...

# %%
# Type of the df variable is a "DataFrame"
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# To store the 1st 5-records in another csv file
# Create a different data frame to save your original data

df_first_5_records = df.head()
df_first_5_records.to_csv("first_5_records.csv")

# %%
# Show the current directory path
import os
os.getcwd()
# Out:
# 'E:\\AnacondaWorkspace\\ds_masters\\2_Data_Analysis\\1_PANDAS'

# %%
# To list out the files in the current directory folder 
# Here you can see the above command has create a csv file "first_5_records.csv"
# !dir
# Out:
#  Volume in drive E is New Volume
#  Volume Serial Number is FC35-E134
#
#  Directory of E:\AnacondaWorkspace\ds_masters\2_Data_Analysis\1_PANDAS
#
# 02/17/2023  04:29 AM    <DIR>          .
# 02/17/2023  04:29 AM    <DIR>          ..
# 02/17/2023  12:11 AM    <DIR>          .ipynb_checkpoints
# 02/17/2023  04:29 AM            42,451 1_Intro_to_pandas.ipynb
# 02/17/2023  04:50 AM               423 first_5_records.csv
# 02/16/2023  10:08 PM                12 README.md
#                3 File(s)         42,886 bytes
#                3 Dir(s)  260,370,092,032 bytes free

# %%
# Show the csv file we created
pd.read_csv('first_5_records.csv')
# Out:
#    Unnamed: 0  Player_Id      Player_Name        DOB Batting_Hand  \
# 0           0          1       SC Ganguly   8-Jul-72    Left_Hand
# 1           1          2      BB McCullum  27-Sep-81   Right_Hand
# 2           2          3       RT Ponting  19-Dec-74   Right_Hand
# 3           3          4        DJ Hussey  15-Jul-77   Right_Hand
# 4           4          5  Mohammad Hafeez  17-Oct-80   Right_Hand
#
#         Bowling_Skill      Country  Is_Umpire  Unnamed: 7
# 0    Right-arm medium        India          0         NaN
# 1    Right-arm medium  New Zealand          0         NaN
# 2    Right-arm medium    Australia          0         NaN
# 3  Right-arm offbreak    Australia          0         NaN
# 4  Right-arm offbreak     Pakistan          0         NaN

# %%
# Replace the ',' delimiter with '#' delimiter
# read the data with out comma separated values
# create a dataset with '#' as a delimiter

df_with_hash_delimiter = df.head(len(df))
#df_with_hash_delimiter.to_csv('../dataset/df_with_hash_delimiter.csv')

df_with_hash_delimiter = pd.read_csv('../dataset/df_with_hash_delimiter.csv')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df_with_hash_delimiter
# Out:
#     #Player_Id#Player_Name#DOB#Batting_Hand#Bowling_Skill#Country#Is_Umpire#Unnamed: 7
# 0    0#1#SC Ganguly#8-Jul-72#Left_Hand#Right-arm me...
# 1    1#2#BB McCullum#27-Sep-81#Right_Hand#Right-arm...
# 2    2#3#RT Ponting#19-Dec-74#Right_Hand#Right-arm ...
# 3    3#4#DJ Hussey#15-Jul-77#Right_Hand#Right-arm o...
# 4    4#5#Mohammad Hafeez#17-Oct-80#Right_Hand#Right...
# ..                                                 ...
# 518                    518#519#Subroto Das####India#1#
# 519                   519#520#K Srinivasan####India#1#
# 520                      520#521#VK Sharma####India#1#
# 521  521#523#AV Wankhade#14-Mar-92#Right_Hand##Indi...
# 522  522#524#B Aparajith#8-Jul-94#Right_Hand#Right-...
#
# [523 rows x 1 columns]

# %%
df_with_hash_delimiter = pd.read_csv('../dataset/df_with_hash_delimiter.csv', sep='#')

# %%
df_with_hash_delimiter
# Out:
#      Unnamed: 0  Player_Id      Player_Name        DOB Batting_Hand  \
# 0             0          1       SC Ganguly   8-Jul-72    Left_Hand
# 1             1          2      BB McCullum  27-Sep-81   Right_Hand
# 2             2          3       RT Ponting  19-Dec-74   Right_Hand
# 3             3          4        DJ Hussey  15-Jul-77   Right_Hand
# 4             4          5  Mohammad Hafeez  17-Oct-80   Right_Hand
# ..          ...        ...              ...        ...          ...
# 518         518        519      Subroto Das        NaN          NaN
# 519         519        520     K Srinivasan        NaN          NaN
# 520         520        521        VK Sharma        NaN          NaN
# 521         521        523      AV Wankhade  14-Mar-92   Right_Hand
# 522         522        524      B Aparajith   8-Jul-94   Right_Hand
#
#           Bowling_Skill      Country  Is_Umpire  Unnamed: 7
# 0      Right-arm medium        India          0         NaN
# ...
